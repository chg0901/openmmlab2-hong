# %% [markdown]
# # Ear目标检测-训练
# Base 同济子豪兄 2023-4-5 三角板目标检测

# %% [markdown]
# ## 进入mmdetection主目录

# %%
import os
os.chdir('mmdetection')

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# 建议在命令行中运行
# !python tools/train.py data/rtmdet_tiny_Ear.py
# Out:
# 06/04 15:01:16 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 528593298
#     GPU 0: NVIDIA GeForce GTX 1080 Ti
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %%
# 建议在命令行中运行
# !python tools/train.py data/rtmdet_tiny_Ear.py
# Out:
# 06/04 15:36:11 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 586041968
#     GPU 0: NVIDIA GeForce GTX 1080 Ti
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 在`work_dirs`目录下，查看训练日志和训练得到的模型权重文件

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py data/rtmdet_tiny_Ear.py \
                      work_dirs/rtmdet_tiny_Ear/best_coco_bbox_mAP_epoch_49.pth
# Out:
# 06/04 17:04:56 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1477247904
#     GPU 0: NVIDIA GeForce GTX 1080 Ti
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %%
# !python tools/test.py data/rtmdet_tiny_Ear.py \
                      work_dirs/rtmdet_tiny_Ear/epoch_200.pth
# Out:
# 06/04 16:46:57 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1633002151
#     GPU 0: NVIDIA GeForce GTX 1080 Ti
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %%
# !python tools/test.py data/rtmdet_tiny_Ear.py \
                      work_dirs/rtmdet_tiny_Ear/best_coco_bbox_mAP_epoch_196.pth
# Out:
# 06/04 16:54:36 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 404663773
#     GPU 0: NVIDIA GeForce GTX 1080 Ti
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...
